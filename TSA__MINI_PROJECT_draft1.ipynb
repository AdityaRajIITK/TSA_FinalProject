# %%
import pandas as pd
import  lxml
print(f'''
pandas -> {pd.__version__}
lxml -> {lxml.__version__}
''')
# Out:
# pandas -> 2.0.1
# lxml -> 4.9.2

# %%
raw_url = 'https://raw.githubusercontent.com/FuTSA23/time-series-analysis-datasets/da059e9f430e1337f7b437609ad2488480465882/Complete_Blasting_info%20(1).csv'
df = pd.read_csv(raw_url, parse_dates=[['Date', 'Time']])

# %%
df=df.set_index('Date_Time')
df
# Out:
#                      Unnamed: 0  PM10 (µg/m3)  NO (µg/m3)  PM2.5 (µg/m3)
# Date_Time
# 2023-02-01 00:00:00           0          95.0   14.484070           35.0  \
# 2023-02-01 00:15:00           1          95.0   14.484070           35.0
# 2023-02-01 00:30:00           2          95.0   15.835914           35.0
# 2023-02-01 00:45:00           3         122.0   15.914518           34.0
# 2023-02-01 01:00:00           4         122.0   16.035640           34.0
# ...                         ...           ...         ...            ...
# 2023-05-01 22:45:00        8635          19.0   17.900000           11.0
# 2023-05-01 23:00:00        8636          19.0   17.900000           11.0
# 2023-05-01 23:15:00        8637          19.0   19.600000           11.0
# 2023-05-01 23:30:00        8638          19.0   20.800000           11.0
# 2023-05-01 23:45:00        8639          32.0   21.800000            6.0
#
#                      NO2 (µg/m3)  NOX (ppb)  CO (mg/m3)  SO2 (µg/m3)
# Date_Time
# ...

# %%
df.shape
# Out:
# (8640, 11)

# %%
df.head()
# Out:
#                      Unnamed: 0  PM10 (µg/m3)  NO (µg/m3)  PM2.5 (µg/m3)
# Date_Time
# 2023-02-01 00:00:00           0          95.0   14.484070           35.0  \
# 2023-02-01 00:15:00           1          95.0   14.484070           35.0
# 2023-02-01 00:30:00           2          95.0   15.835914           35.0
# 2023-02-01 00:45:00           3         122.0   15.914518           34.0
# 2023-02-01 01:00:00           4         122.0   16.035640           34.0
#
#                      NO2 (µg/m3)  NOX (ppb)  CO (mg/m3)  SO2 (µg/m3)
# Date_Time
# 2023-02-01 00:00:00         90.1       56.2        0.31    11.986833  \
# 2023-02-01 00:15:00         88.0       55.1        0.33    11.986833
# 2023-02-01 00:30:00         87.7       55.2        0.38    10.912796
# 2023-02-01 00:45:00         88.9       55.7        0.38    10.613291
# 2023-02-01 01:00:00         90.0       55.8        0.38     7.362361
#
#                      NH3 (µg/m3)  Ozone (µg/m3)  Benzene (µg/m3)
# Date_Time
# ...

# %%
for column_name in df.columns:
    column = df[column_name]
    # Get the count of Zeros in column 
    count = (column == 0).sum()
    print('Count of zeros in column ', column_name, ' is : ', count)
# Out:
# Count of zeros in column  Unnamed: 0  is :  1
# Count of zeros in column  PM10 (µg/m3)  is :  0
# Count of zeros in column  NO (µg/m3)  is :  0
# Count of zeros in column  PM2.5 (µg/m3)  is :  0
# Count of zeros in column  NO2 (µg/m3)  is :  0
# Count of zeros in column  NOX (ppb)  is :  0
# Count of zeros in column  CO (mg/m3)  is :  0
# Count of zeros in column  SO2 (µg/m3)  is :  0
# Count of zeros in column  NH3 (µg/m3)  is :  0
# Count of zeros in column  Ozone (µg/m3)  is :  0
# Count of zeros in column  Benzene (µg/m3)  is :  0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# PM10 (µg/m3)       0
# NO (µg/m3)         0
# PM2.5 (µg/m3)      0
# NO2 (µg/m3)        0
# NOX (ppb)          0
# CO (mg/m3)         0
# SO2 (µg/m3)        0
# NH3 (µg/m3)        0
# Ozone (µg/m3)      0
# Benzene (µg/m3)    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Unnamed: 0         0
# PM10 (µg/m3)       0
# NO (µg/m3)         0
# PM2.5 (µg/m3)      0
# NO2 (µg/m3)        0
# NOX (ppb)          0
# CO (mg/m3)         0
# SO2 (µg/m3)        0
# NH3 (µg/m3)        0
# Ozone (µg/m3)      0
# Benzene (µg/m3)    0
# dtype: int64

# %% [markdown]
# There are no null values in the dataset.

# %%
plot = df.plot(
            title='Pollutant',
            ylabel= 'amount')

# %%
df=df.drop(['Unnamed: 0'], axis=1)

# %%
df
# Out:
#                      PM10 (µg/m3)  NO (µg/m3)  PM2.5 (µg/m3)  NO2 (µg/m3)
# Date_Time
# 2023-02-01 00:00:00          95.0   14.484070           35.0         90.1  \
# 2023-02-01 00:15:00          95.0   14.484070           35.0         88.0
# 2023-02-01 00:30:00          95.0   15.835914           35.0         87.7
# 2023-02-01 00:45:00         122.0   15.914518           34.0         88.9
# 2023-02-01 01:00:00         122.0   16.035640           34.0         90.0
# ...                           ...         ...            ...          ...
# 2023-05-01 22:45:00          19.0   17.900000           11.0        100.0
# 2023-05-01 23:00:00          19.0   17.900000           11.0        100.0
# 2023-05-01 23:15:00          19.0   19.600000           11.0        100.2
# 2023-05-01 23:30:00          19.0   20.800000           11.0        100.2
# 2023-05-01 23:45:00          32.0   21.800000            6.0         98.8
#
#                      NOX (ppb)  CO (mg/m3)  SO2 (µg/m3)  NH3 (µg/m3)
# ...

# %%
plot = df.plot(
            title='Pollutant',
            ylabel= 'amount',figsize=(12,6))

# %%
plot = df.plot(
            title='Pollutant',
            ylabel= 'amount',figsize=(12,6))

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,6))
plt.plot(df.iloc[2016:2113],)
plt.ylabel('amount')
plt.legend(df.columns)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
